# %%
import pandas as pd
import numpy as np

# %%
vehicles_df = pd.read_csv('vehicles/vehicles.csv')
vehicles_df.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %%
vehicles_df.pivot_table(index=["Vehicle Class"])
# Out:
#                                     CO2 Emission Grams/Mile   City MPG  \
# Vehicle Class
# Compact Cars                                     396.758088  20.570685
# Large Cars                                       484.391278  16.130310
# Midsize Cars                                     432.861095  18.950775
# Midsize Station Wagons                           432.128533  18.360577
# Midsize-Large Station Wagons                     452.981561  17.590837
# Minicompact Cars                                 443.861984  18.380363
# Minivan - 2WD                                    469.287896  16.679758
# Minivan - 4WD                                    504.595699  15.425532
# Small Pickup Trucks                              450.039261  18.416031
# Small Pickup Trucks 2WD                          454.361734  17.922693
# Small Pickup Trucks 4WD                          497.689565  16.405000
# Small Sport Utility Vehicle 2WD                  378.034759  21.147059
# ...

# %%
vehicles_df.pivot_table(index=["Vehicle Class"], columns=["Cylinders"])
# Out:
#                                    CO2 Emission Grams/Mile              \
# Cylinders                                             2.0         3.0
# Vehicle Class
# Compact Cars                                           NaN  243.666667
# Large Cars                                             NaN         NaN
# Midsize Cars                                           NaN         NaN
# Midsize Station Wagons                                 NaN         NaN
# Midsize-Large Station Wagons                           NaN         NaN
# Minicompact Cars                                493.722222  234.692515
# Minivan - 2WD                                          NaN         NaN
# Minivan - 4WD                                          NaN         NaN
# Small Pickup Trucks                                    NaN         NaN
# Small Pickup Trucks 2WD                                NaN         NaN
# Small Pickup Trucks 4WD                                NaN         NaN
# ...

# %%
vehicles_df.pivot_table(index=["Vehicle Class"],columns=['Cylinders'], values=["Combined MPG"], aggfunc=np.sum)
# Out:
#                                    Combined MPG                           \
# Cylinders                                  2.0     3.0      4.0     5.0
# Vehicle Class
# Compact Cars                                NaN   436.0  86273.0  4630.0
# Large Cars                                  NaN     NaN   3520.0     NaN
# Midsize Cars                                NaN     NaN  39211.0  1636.0
# Midsize Station Wagons                      NaN     NaN   3692.0  1497.0
# Midsize-Large Station Wagons                NaN     NaN   6854.0   628.0
# Minicompact Cars                           18.0   730.0   9555.0   203.0
# Minivan - 2WD                               NaN     NaN    710.0     NaN
# Minivan - 4WD                               NaN     NaN      NaN     NaN
# Small Pickup Trucks                         NaN     NaN   7577.0     NaN
# Small Pickup Trucks 2WD                     NaN     NaN   5158.0   578.0
# Small Pickup Trucks 4WD                     NaN     NaN   1536.0   558.0
# ...

# %%
vehicles_df.pivot_table(index=["Vehicle Class"], columns=["Cylinders"], values=["Combined MPG"], fill_value=0)
# Out:
#                                    Combined MPG                        \
# Cylinders                                  2.0        3.0        4.0
# Vehicle Class
# Compact Cars                           0.000000  36.333333  25.381877
# Large Cars                             0.000000   0.000000  24.275862
# Midsize Cars                           0.000000   0.000000  25.830698
# Midsize Station Wagons                 0.000000   0.000000  23.515924
# Midsize-Large Station Wagons           0.000000   0.000000  20.769697
# Minicompact Cars                      18.000000  38.421053  25.078740
# Minivan - 2WD                          0.000000   0.000000  21.515152
# Minivan - 4WD                          0.000000   0.000000   0.000000
# Small Pickup Trucks                    0.000000   0.000000  21.403955
# Small Pickup Trucks 2WD                0.000000   0.000000  21.491667
# Small Pickup Trucks 4WD                0.000000   0.000000  19.692308
# ...

# %%
vehicles_df.pivot_table(index=["Vehicle Class"],columns=['Cylinders'], values=["Combined MPG"], aggfunc=np.sum)
# Out:
#                                    Combined MPG                           \
# Cylinders                                  2.0     3.0      4.0     5.0
# Vehicle Class
# Compact Cars                                NaN   436.0  86273.0  4630.0
# Large Cars                                  NaN     NaN   3520.0     NaN
# Midsize Cars                                NaN     NaN  39211.0  1636.0
# Midsize Station Wagons                      NaN     NaN   3692.0  1497.0
# Midsize-Large Station Wagons                NaN     NaN   6854.0   628.0
# Minicompact Cars                           18.0   730.0   9555.0   203.0
# Minivan - 2WD                               NaN     NaN    710.0     NaN
# Minivan - 4WD                               NaN     NaN      NaN     NaN
# Small Pickup Trucks                         NaN     NaN   7577.0     NaN
# Small Pickup Trucks 2WD                     NaN     NaN   5158.0   578.0
# Small Pickup Trucks 4WD                     NaN     NaN   1536.0   558.0
# ...

# %%
vehicles_df['City MPG'].corr(vehicles_df['Highway MPG'])
# Out:
# 0.92385558852884

# %%
vehicles_df.corr()
# Out:
#                              Year  Engine Displacement  Cylinders  \
# Year                     1.000000             0.037876   0.082469
# Engine Displacement      0.037876             1.000000   0.901858
# Cylinders                0.082469             0.901858   1.000000
# Fuel Barrels/Year       -0.221084             0.789752   0.739517
# City MPG                 0.161818            -0.740317  -0.703866
# Highway MPG              0.267259            -0.715039  -0.650287
# Combined MPG             0.204751            -0.746782  -0.698648
# CO2 Emission Grams/Mile -0.222300             0.803520   0.752393
# Fuel Cost/Year          -0.091913             0.769678   0.778153
#
#                          Fuel Barrels/Year  City MPG  Highway MPG  \
# Year                             -0.221084  0.161818     0.267259
# Engine Displacement               0.789752 -0.740317    -0.715039
# Cylinders                         0.739517 -0.703866    -0.650287
# ...

# %%
vehicles_df.corr(method='spearman')
# Out:
#                              Year  Engine Displacement  Cylinders  \
# Year                     1.000000             0.051370   0.068727
# Engine Displacement      0.051370             1.000000   0.927979
# Cylinders                0.068727             0.927979   1.000000
# Fuel Barrels/Year       -0.214857             0.827152   0.784595
# City MPG                 0.157137            -0.848167  -0.818672
# Highway MPG              0.266934            -0.754080  -0.698356
# Combined MPG             0.205080            -0.824065  -0.783362
# CO2 Emission Grams/Mile -0.215108             0.831333   0.788777
# Fuel Cost/Year          -0.091437             0.794755   0.790481
#
#                          Fuel Barrels/Year  City MPG  Highway MPG  \
# Year                             -0.214857  0.157137     0.266934
# Engine Displacement               0.827152 -0.848167    -0.754080
# Cylinders                         0.784595 -0.818672    -0.698356
# ...

# %%
vehicles_df['City MPG'].corr(vehicles_df['Highway MPG'], method="kendall")
# Out:
# 0.8171408108342495

# %%
vehicles_df.pivot_table(index=["Vehicle Class"],columns=['Cylinders'],values=["Combined MPG"], aggfunc={'Combined MPG':'mean'})
# Out:
#                                    Combined MPG                        \
# Cylinders                                  2.0        3.0        4.0
# Vehicle Class
# Compact Cars                                NaN  36.333333  25.381877
# Large Cars                                  NaN        NaN  24.275862
# Midsize Cars                                NaN        NaN  25.830698
# Midsize Station Wagons                      NaN        NaN  23.515924
# Midsize-Large Station Wagons                NaN        NaN  20.769697
# Minicompact Cars                      18.000000  38.421053  25.078740
# Minivan - 2WD                               NaN        NaN  21.515152
# Minivan - 4WD                               NaN        NaN        NaN
# Small Pickup Trucks                         NaN        NaN  21.403955
# Small Pickup Trucks 2WD                     NaN        NaN  21.491667
# Small Pickup Trucks 4WD                     NaN        NaN  19.692308
# ...

# %%
 df = pd.DataFrame({"A": ["foo", "foo", "foo", "foo", "foo",
...                          "bar", "bar", "bar", "bar"],
...                    "B": ["one", "one", "one", "two", "two",
...                          "one", "one", "two", "two"],
...                    "C": ["small", "large", "large", "small",
...                          "small", "large", "small", "small",
...                          "large"],
...                    "D": [1, 2, 2, 3, 3, 4, 5, 6, 7],
...                    "E": [2, 4, 5, 5, 6, 6, 8, 9, 9]})

# %%
df
# Out:
#      A    B      C  D  E
# 0  foo  one  small  1  2
# 1  foo  one  large  2  4
# 2  foo  one  large  2  5
# 3  foo  two  small  3  5
# 4  foo  two  small  3  6
# 5  bar  one  large  4  6
# 6  bar  one  small  5  8
# 7  bar  two  small  6  9
# 8  bar  two  large  7  9

# %%
table = pd.pivot_table(df,columns=['C'], values=['D', 'E'], index=['A', 'C'],
...                     aggfunc={'D': np.mean,
...                              'E': [min, max, np.mean]})

# %%
table
# Out:
#               D               E
#            mean             max        mean             min
# C         large     small large small large     small large small
# A   C
# bar large   5.5       NaN   9.0   NaN   7.5       NaN   6.0   NaN
#     small   NaN  5.500000   NaN   9.0   NaN  8.500000   NaN   8.0
# foo large   2.0       NaN   5.0   NaN   4.5       NaN   4.0   NaN
#     small   NaN  2.333333   NaN   6.0   NaN  4.333333   NaN   2.0
