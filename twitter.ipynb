# %%
import sys 
# !{sys.executable} -m pip install requests tweepy pandas

# %%
import tweepy
import pandas as pd

API_KEY = "kKSLcLRILR21nZPRNBerIexDe"
API_SECRET = "GDn3ZBPgtLybJypyq2mojqyvSqbmVGVS5d2HmkXZCJDdCxkRxD"
ACCESS_TOKEN = "143217474-8I4Vm23IxwKA4Gvic46lKr10BM7Pz6X6YEamqNoL"
ACCESS_TOKEN_SECRET = "Hq0aLkaquoUVRu54Dn6ll7GOSXVj98mCk7fLbfcj9QIQF"

auth = tweepy.OAuthHandler(API_KEY, API_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
api = tweepy.API(auth)
api

# %%
def get_followers(user, count=100):
    results = api.followers(user, count=count)
    followers = [pd.Series(follower._json) for follower in results]
    df = pd.DataFrame(followers)
    return df

ironhack = get_followers('ironhack')
ironhack.head(10)
# Out:
#                     id               id_str                 name  \
# 0            174183860            174183860       Julia Kornmann
# 1  1051799666671673344  1051799666671673344       marcos brandão
# 2  1149702536242356229  1149702536242356229         ale.rpascual
# 3            237637895            237637895        Almudena Cano
# 4           3106496661           3106496661              LookFar
# 5             18247201             18247201           CarlosBode
# 6            997067862            997067862  Manuel Calero Solís
# 7  1148886575264292864  1148886575264292864  hola@tailor-hub.com
# 8  1148813668131328000  1148813668131328000          Neha Sharma
# 9           2725462737           2725462737               Manein
#
#        screen_name                    location  \
# 0       Julia_3012            Nürnberg, Bayern
# 1       MBrandao66  Copacabana, Rio de Janeiro
# 2      AleRpascual
# 3         almukano                      begues
# ...
