# %%
import sys
# !{sys.executable} -m pip install requests pandas spotipy

# %%
import requests


data = requests.get('https://rickandmortyapi.com/api/character')
data = data.json()
data
# Out:
# {'info': {'count': 493,
#   'pages': 25,
#   'next': 'https://rickandmortyapi.com/api/character/?page=2',
#   'prev': ''},
#  'results': [{'id': 1,
#    'name': 'Rick Sanchez',
#    'status': 'Alive',
#    'species': 'Human',
#    'type': '',
#    'gender': 'Male',
#    'origin': {'name': 'Earth (C-137)',
#     'url': 'https://rickandmortyapi.com/api/location/1'},
#    'location': {'name': 'Earth (Replacement Dimension)',
#     'url': 'https://rickandmortyapi.com/api/location/20'},
#    'image': 'https://rickandmortyapi.com/api/character/avatar/1.jpeg',
#    'episode': ['https://rickandmortyapi.com/api/episode/1',
#     'https://rickandmortyapi.com/api/episode/2',
#     'https://rickandmortyapi.com/api/episode/3',
#     'https://rickandmortyapi.com/api/episode/4',
#     'https://rickandmortyapi.com/api/episode/5',
#     'https://rickandmortyapi.com/api/episode/6',
#     'https://rickandmortyapi.com/api/episode/7',
#     'https://rickandmortyapi.com/api/episode/8',
# ...

# %%
import pandas as pd
df = pd.DataFrame(data['results'])
df
# Out:
#                      created  \
# 0   2017-11-04T18:48:46.250Z
# 1   2017-11-04T18:50:21.651Z
# 2   2017-11-04T19:09:56.428Z
# 3   2017-11-04T19:22:43.665Z
# 4   2017-11-04T19:26:56.301Z
# 5   2017-11-04T19:50:28.250Z
# 6   2017-11-04T19:59:20.523Z
# 7   2017-11-04T20:03:34.737Z
# 8   2017-11-04T20:06:54.976Z
# 9   2017-11-04T20:19:09.017Z
# 10  2017-11-04T20:20:20.965Z
# 11  2017-11-04T20:32:33.144Z
# 12  2017-11-04T20:33:30.779Z
# 13  2017-11-04T20:51:31.373Z
# 14  2017-11-04T20:56:13.215Z
# 15  2017-11-04T21:12:45.235Z
# 16  2017-11-04T22:21:24.481Z
# 17  2017-11-04T22:25:29.008Z
# 18  2017-11-04T22:28:13.756Z
# 19  2017-11-04T22:34:53.659Z
#
#                                               episode   gender  id  \
# 0   [https://rickandmortyapi.com/api/episode/1, ht...     Male   1
# 1   [https://rickandmortyapi.com/api/episode/1, ht...     Male   2
# 2   [https://rickandmortyapi.com/api/episode/6, ht...   Female   3
# ...

# %%
git_events = requests.get('https://api.github.com/events')
git_events = git_events.json()
git_events
# Out:
# [{'id': '10015954188',
#   'type': 'PushEvent',
#   'actor': {'id': 29139614,
#    'login': 'renovate[bot]',
#    'display_login': 'renovate',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/renovate[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29139614?'},
#   'repo': {'id': 66407038,
#    'name': 'telus/tds-core',
#    'url': 'https://api.github.com/repos/telus/tds-core'},
#   'payload': {'push_id': 3819344757,
#    'size': 7,
#    'distinct_size': 1,
#    'ref': 'refs/heads/renovate/file-loader-4.x',
#    'head': '6e19b81bb20a29a6eb46ba5815274288ee070e48',
#    'before': 'cffadfee3a87019fcaeab4bc4ffdcf2b8a6a545b',
#    'commits': [{'sha': 'db4c90492a0556dd0bd698dd6ed74f669f9e6cc9',
#      'author': {'email': 'anatolii.gorovyi@telus.com',
#       'name': 'Anatolii Gorovyi'},
#      'message': 'fix(core-unordered-list): leave only 1px leftpadding from bullet',
#      'distinct': False,
# ...

# %%
df_events = pd.DataFrame(git_events)
df_events
# Out:
#                                                 actor            created_at  \
# 0   {'id': 29139614, 'login': 'renovate[bot]', 'di...  2019-07-15T21:30:04Z
# 1   {'id': 39814207, 'login': 'pull[bot]', 'displa...  2019-07-15T21:30:04Z
# 2   {'id': 27856297, 'login': 'dependabot-preview[...  2019-07-15T21:30:04Z
# 3   {'id': 27790417, 'login': 'qjl1569', 'display_...  2019-07-15T21:30:04Z
# 4   {'id': 8676741, 'login': 'liesauer', 'display_...  2019-07-15T21:30:04Z
# 5   {'id': 42983685, 'login': 'foggybrains', 'disp...  2019-07-15T21:30:04Z
# 6   {'id': 30536864, 'login': 'signcla-test-signed...  2019-07-15T21:30:04Z
# 7   {'id': 8739300, 'login': 'kyleplump', 'display...  2019-07-15T21:30:04Z
# 8   {'id': 27856297, 'login': 'dependabot-preview[...  2019-07-15T21:30:04Z
# 9   {'id': 32424503, 'login': 'Pachwenko', 'displa...  2019-07-15T21:30:04Z
# 10  {'id': 40587912, 'login': 'supermobiteam2', 'd...  2019-07-15T21:30:04Z
# ...

# %%
from pandas.io.json import json_normalize

df_events_2 = json_normalize(git_events)
df_events_2
# Out:
#                                      actor.avatar_url  \
# 0   https://avatars.githubusercontent.com/u/29139614?
# 1   https://avatars.githubusercontent.com/u/39814207?
# 2   https://avatars.githubusercontent.com/u/27856297?
# 3   https://avatars.githubusercontent.com/u/27790417?
# 4    https://avatars.githubusercontent.com/u/8676741?
# 5   https://avatars.githubusercontent.com/u/42983685?
# 6   https://avatars.githubusercontent.com/u/30536864?
# 7    https://avatars.githubusercontent.com/u/8739300?
# 8   https://avatars.githubusercontent.com/u/27856297?
# 9   https://avatars.githubusercontent.com/u/32424503?
# 10  https://avatars.githubusercontent.com/u/40587912?
# 11   https://avatars.githubusercontent.com/u/2440723?
# 12   https://avatars.githubusercontent.com/u/4109364?
# 13   https://avatars.githubusercontent.com/u/1307667?
# 14  https://avatars.githubusercontent.com/u/35314292?
# 15  https://avatars.githubusercontent.com/u/46820300?
# ...

# %%
headers = {'authorization':'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiI1ZDE0NDBiNDVkMTlhZTAwMTc0ZTUzOWUiLCJlbWFpbCI6Im9zQGZpeHRlci5vcmciLCJpYXQiOjE1NjI5NjQ4NzQsImV4cCI6MTU2MzIyNDA3NH0.n6rt0U_CRjr3w3CtcSw9U1ueajEYSyUc4j_uWyGkDn4'}
publications = requests.get('https://amg-api.herokuapp.com/publications',headers=headers )
publications = publications.json()
publications_df = pd.DataFrame(publications)
publications_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-336b75ed552a> in <module>
#       2 publications = requests.get('https://amg-api.herokuapp.com/publications',headers=headers )
#       3 publications = publications.json()
# ----> 4 publications_df = pd.DataFrame(publications)
#       5 publications_df
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     390                                  dtype=dtype, copy=copy)
#     391         elif isinstance(data, dict):
# --> 392             mgr = init_dict(data, index, columns, dtype=dtype)
#     393         elif isinstance(data, ma.MaskedArray):
#     394             import numpy.ma.mrecords as mrecords
#
# /usr/local/lib/python3.7/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
# ...

# %%
data =  {
        "name": "Oswaldinho",
        "occupation": "teacher",
        "debt": True,
        "weapon": "food"
        }
headers = {
    'Content-Type':'applications/json'
}
new_student = requests.post('https://ih-crud-api.herokuapp.com/characters',data=data)
new_student = new_student.json()
new_student

# %%
import spotipy
from spotipy import oauth2,util
from spotipy.oauth2 import SpotifyClientCredentials


SPOTIPY_CLIENT_ID='aafdecc35e8e42a39e0b28a813f9eaf1'
SPOTIPY_CLIENT_SECRET='178152db9e9d45d586c1a24b09ce2f4a'
SPOTIPY_REDIRECT_URI='http://localhost:8888'

#token = util.prompt_for_user_token(username='ironmusic',client_id=SPOTIPY_CLIENT_ID,client_secret=SPOTIPY_CLIENT_SECRET, redirect_uri=SPOTIPY_REDIRECT_URI)
token= 'BQCD2Wc4_WXJSFk6x2r37v1q8Lm79KQUMZzq0f48UjEYoWfL8covveWLdjruBaZ4gLfJv7yxCc6JSNQxbqHbv2Ma4W_aHhDoINbnZTtvYDFkdbd2z9X4BYRSmIiogsqCJakBZ7hKC_kQDLCF-c30D5NftwRCzS_bLQt2e9aD'

# %%
#token='BQASWR5IN35J_SHTT9Gr0ocOV4nXPuv-IdGXGwNSETqyXYHhKjWoK6KZ4Su98-AgnrMifWSYqZzfxj0BihcmGZ2FyCwDg93PJFObrn0We9g2KyjvvBpIHM3k0R-7lm897fO2-dUEY5l93-XAIiVA6T_AMYFLXOjk42iKh8yn'
spotify = spotipy.Spotify(auth=token)
results = spotify.search(q='track:' + 'farruko', type='track')
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=track%3Afarruko&type=track&market=MX&offset=0&limit=10',
#   'items': [{'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2R21vXR83lH98kGeO99Y66'},
#        'href': 'https://api.spotify.com/v1/artists/2R21vXR83lH98kGeO99Y66',
#        'id': '2R21vXR83lH98kGeO99Y66',
#        'name': 'Anuel AA',
#        'type': 'artist',
#        'uri': 'spotify:artist:2R21vXR83lH98kGeO99Y66'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
# ...

# %%
r_df = results['tracks']
r_df

#import IPython.display as ipd
#ipd.Audio('audio/conga_groove.wav')
# Out:
# {'href': 'https://api.spotify.com/v1/search?query=track%3Afarruko&type=track&market=MX&offset=0&limit=10',
#  'items': [{'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2R21vXR83lH98kGeO99Y66'},
#       'href': 'https://api.spotify.com/v1/artists/2R21vXR83lH98kGeO99Y66',
#       'id': '2R21vXR83lH98kGeO99Y66',
#       'name': 'Anuel AA',
#       'type': 'artist',
#       'uri': 'spotify:artist:2R21vXR83lH98kGeO99Y66'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
# ...
