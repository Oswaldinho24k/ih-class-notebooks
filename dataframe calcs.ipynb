# %%
import pandas as pd
import numpy as np

# %%
animals = pd.read_csv('animals.csv')
animals.head()
# Out:
#    brainwt   bodywt      animal
# 0    3.385   44.500  Arctic_fox
# 1    0.480   15.499  Owl_monkey
# 2    1.350    8.100      Beaver
# 3  464.983  423.012         Cow
# 4   36.328  119.498   Gray_wolf

# %%
animals['bodywtkg'] = animals['bodywt'] * 0.45359237
animals.head()
# Out:
#    brainwt   bodywt      animal    bodywtkg
# 0    3.385   44.500  Arctic_fox   20.184860
# 1    0.480   15.499  Owl_monkey    7.030228
# 2    1.350    8.100      Beaver    3.674098
# 3  464.983  423.012         Cow  191.875016
# 4   36.328  119.498   Gray_wolf   54.203381

# %%
animals['wtratio'] = animals['bodywt'] / animals['brainwt']
animals.head()
# Out:
#    brainwt   bodywt      animal    bodywtkg    wtratio
# 0    3.385   44.500  Arctic_fox   20.184860  13.146233
# 1    0.480   15.499  Owl_monkey    7.030228  32.289583
# 2    1.350    8.100      Beaver    3.674098   6.000000
# 3  464.983  423.012         Cow  191.875016   0.909736
# 4   36.328  119.498   Gray_wolf   54.203381   3.289419

# %%
animals['wtratiozerocheck'] = np.where(animals['brainwt'] != 0, animals['bodywt'] / animals['brainwt'], 0)
animals.head()
# Out:
#    brainwt   bodywt      animal    bodywtkg    wtratio  wtratiozerocheck
# 0    3.385   44.500  Arctic_fox   20.184860  13.146233         13.146233
# 1    0.480   15.499  Owl_monkey    7.030228  32.289583         32.289583
# 2    1.350    8.100      Beaver    3.674098   6.000000          6.000000
# 3  464.983  423.012         Cow  191.875016   0.909736          0.909736
# 4   36.328  119.498   Gray_wolf   54.203381   3.289419          3.289419

# %%
animals['sum'] = animals.sum(axis=1)
animals
# Out:
#      brainwt    bodywt                     animal     bodywtkg    wtratio  \
# 0      3.385    44.500                 Arctic_fox    20.184860  13.146233
# 1      0.480    15.499                 Owl_monkey     7.030228  32.289583
# 2      1.350     8.100                     Beaver     3.674098   6.000000
# 3    464.983   423.012                        Cow   191.875016   0.909736
# 4     36.328   119.498                  Gray_wolf    54.203381   3.289419
# 5     27.660   114.996                       Goat    52.161308   4.157484
# 6     14.831    98.199                   Roe_deer    44.542317   6.621199
# 7      1.040     5.500                 Guinea_pig     2.494758   5.288462
# 8      4.190    57.998                     Vervet    26.307450  13.842005
# 9      0.425     6.400                 Chinchilla     2.902991  15.058824
# 10     0.101     4.000            Ground_squirrel     1.814369  39.603960
# 11     0.920     5.700                     Arctic     2.585477   6.195652
# ...

# %%
vehicles = pd.read_csv('vehicles/vehicles.csv')
vehicles
# Out:
#                         Make                Model  Year  Engine Displacement  \
# 0                 AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1                 AM General     FJ8c Post Office  1984                  4.2
# 2                 AM General  Post Office DJ5 2WD  1985                  2.5
# 3                 AM General  Post Office DJ8 2WD  1985                  4.2
# 4           ASC Incorporated                  GNX  1987                  3.8
# 5                      Acura          2.2CL/3.0CL  1997                  2.2
# 6                      Acura          2.2CL/3.0CL  1997                  2.2
# 7                      Acura          2.2CL/3.0CL  1997                  3.0
# 8                      Acura          2.3CL/3.0CL  1998                  2.3
# 9                      Acura          2.3CL/3.0CL  1998                  2.3
# 10                     Acura          2.3CL/3.0CL  1998                  3.0
# ...

# %%
vehicles.groupby(['Transmission'])

# %%
vehicles.groupby(['Transmission'])['Highway MPG', 'City MPG', 'Combined MPG'].mean()
# Out:
#                                   Highway MPG   City MPG  Combined MPG
# Transmission
# Auto (AV)                           40.000000  35.000000     37.000000
# Auto (AV-S6)                        25.000000  22.000000     23.000000
# Auto (AV-S8)                        22.000000  20.000000     21.000000
# Auto(A1)                            37.000000  41.000000     39.000000
# Auto(AM-S6)                         32.978261  24.315217     27.554348
# Auto(AM-S7)                         25.300781  17.746094     20.425781
# Auto(AM-S8)                         32.000000  23.666667     26.666667
# Auto(AM-S9)                         22.000000  21.000000     21.000000
# Auto(AM5)                           39.000000  33.666667     36.000000
# Auto(AM6)                           31.345455  23.909091     26.736364
# Auto(AM7)                           22.382166  16.248408     18.420382
# Auto(AM8)                           28.600000  22.400000     24.600000
# ...

# %%
vehicles.groupby(['Fuel Type', 'Cylinders'])['CO2 Emission Grams/Mile'].median()
# Out:
# Fuel Type                    Cylinders
# CNG                          4.0          253.197321
#                              6.0          417.030882
#                              8.0          568.070913
# Diesel                       4.0          308.484848
#                              5.0          391.538462
#                              6.0          439.000000
#                              8.0          598.823529
#                              10.0         598.823529
# Gasoline or E85              4.0          355.480000
#                              6.0          444.350000
#                              8.0          592.466667
# Gasoline or natural gas      4.0          386.391304
#                              6.0          437.000000
#                              8.0          740.583333
# Gasoline or propane          8.0          666.525000
# Midgrade                     6.0          416.000000
#                              8.0          527.000000
# ...

# %%
vehicles.groupby(['Fuel Type', 'Cylinders'])['CO2 Emission Grams/Mile'].agg(['mean', 'sum'])
# Out:
#                                              mean           sum
# Fuel Type                   Cylinders
# CNG                         4.0        257.539637  5.408332e+03
#                             6.0        417.030882  1.251093e+03
#                             8.0        573.309895  2.063916e+04
# Diesel                      4.0        330.909525  1.052292e+05
#                             5.0        425.288362  7.229902e+03
#                             6.0        435.797518  6.580543e+04
#                             8.0        589.949213  2.483686e+05
#                             10.0       590.506536  2.362026e+03
# Gasoline or E85             4.0        359.073842  4.560238e+04
#                             6.0        454.282739  1.630875e+05
#                             8.0        594.649022  4.216062e+05
# Gasoline or natural gas     4.0        383.464097  1.917320e+03
#                             6.0        437.000000  8.740000e+02
# ...

# %%
vehicles.groupby(['Fuel Type', 'Cylinders'])['Fuel Type'].count()
# Out:
# Fuel Type                    Cylinders
# CNG                          4.0             21
#                              6.0              3
#                              8.0             36
# Diesel                       4.0            318
#                              5.0             17
#                              6.0            151
#                              8.0            421
#                              10.0             4
# Gasoline or E85              4.0            127
#                              6.0            359
#                              8.0            709
# Gasoline or natural gas      4.0              5
#                              6.0              2
#                              8.0             13
# Gasoline or propane          8.0              8
# Midgrade                     6.0              5
#                              8.0             69
# Premium                      2.0             22
#                              3.0             26
# ...

# %%
from scipy import stats

def agg_mode(x):
    return stats.mode(x)

# %%
vehicles.groupby("Transmission")["Vehicle Class"].agg(agg_mode)
# Out:
# Transmission
# Auto (AV)                                                 ([Compact Cars], [2])
# Auto (AV-S6)                                              ([Compact Cars], [1])
# Auto (AV-S8)                                              ([Midsize Cars], [1])
# Auto(A1)                                               ([Subcompact Cars], [1])
# Auto(AM-S6)                                              ([Compact Cars], [37])
# Auto(AM-S7)                                          ([Minicompact Cars], [75])
# Auto(AM-S8)                                               ([Compact Cars], [3])
# Auto(AM-S9)                                                ([Two Seaters], [1])
# Auto(AM5)                                                 ([Two Seaters], [12])
# Auto(AM6)                                                ([Compact Cars], [33])
# Auto(AM7)                                                 ([Two Seaters], [89])
# Auto(AM8)                           ([Standard Sport Utility Vehicle 4WD], [3])
# ...

# %%
vehicles.groupby("Vehicle Class").agg('sum')
# Out:
#                                         Year  Engine Displacement  Cylinders  \
# Vehicle Class
# Compact Cars                        10375691              12803.3    25081.0
# Large Cars                           3492348               7233.4    12418.0
# Midsize Cars                         8135906              12794.1    23017.0
# Midsize Station Wagons                833709               1125.9     2152.0
# Midsize-Large Station Wagons         1259633               1802.7     3237.0
# Minicompact Cars                     2429610               3785.8     6986.0
# Minivan - 2WD                         664112               1130.7     1920.0
# Minivan - 4WD                          94238                167.8      282.0
# Small Pickup Trucks                  1042204               1407.8     2436.0
# Small Pickup Trucks 2WD               802651               1208.9     1926.0
# Small Pickup Trucks 4WD               400968                685.4     1045.0
# ...

# %%
vehicles.groupby(['Fuel Type', 'Cylinders']).agg({'CO2 Emission Grams/Mile':{'sum lol':agg_mode}})
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/core/groupby/generic.py:1315: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#                                               CO2 Emission Grams/Mile
#                                                               sum lol
# Fuel Type                   Cylinders
# CNG                         4.0          ([253.19732142857143], [11])
#                             6.0            ([417.0308823529412], [3])
#                             8.0                   ([590.79375], [11])
# Diesel                      4.0           ([299.4117647058824], [44])
#                             5.0           ([363.57142857142856], [5])
#                             6.0           ([391.5384615384616], [21])
#                             8.0          ([598.8235294117648], [135])
# ...

# %%
vehicles
# Out:
#                         Make                Model  Year  Engine Displacement  \
# 0                 AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1                 AM General     FJ8c Post Office  1984                  4.2
# 2                 AM General  Post Office DJ5 2WD  1985                  2.5
# 3                 AM General  Post Office DJ8 2WD  1985                  4.2
# 4           ASC Incorporated                  GNX  1987                  3.8
# 5                      Acura          2.2CL/3.0CL  1997                  2.2
# 6                      Acura          2.2CL/3.0CL  1997                  2.2
# 7                      Acura          2.2CL/3.0CL  1997                  3.0
# 8                      Acura          2.3CL/3.0CL  1998                  2.3
# 9                      Acura          2.3CL/3.0CL  1998                  2.3
# 10                     Acura          2.3CL/3.0CL  1998                  3.0
# ...

# %%
vehicles['Fuel Type']
# Out:
# 0        Regular
# 1        Regular
# 2        Regular
# 3        Regular
# 4        Premium
# 5        Regular
# 6        Regular
# 7        Regular
# 8        Regular
# 9        Regular
# 10       Regular
# 11       Regular
# 12       Regular
# 13       Regular
# 14       Premium
# 15       Premium
# 16       Premium
# 17       Premium
# 18       Premium
# 19       Premium
# 20       Premium
# 21       Premium
# 22       Premium
# 23       Premium
# 24       Premium
# 25       Premium
# 26       Premium
# 27       Premium
# 28       Premium
# 29       Premium
#           ...
# 35922    Premium
# 35923    Premium
# 35924    Regular
# 35925    Regular
# 35926    Regular
# 35927    Regular
# 35928    Regular
# 35929    Regular
# 35930    Regular
# 35931    Regular
# 35932    Premium
# 35933    Premium
# 35934    Premium
# 35935    Premium
# 35936    Premium
# 35937    Premium
# 35938    Premium
# 35939    Premium
# 35940    Premium
# 35941    Premium
# 35942    Premium
# ...

# %%
s1 = pd.Series(['a', 'b', 'c']).fillna('')
s2 = pd.Series(['c', 'd', 'e', 'lol'])
s1.str.replace('a', 'x')
pd.Series(np.intersect1d(s1.values,s2.values))
vehicles.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Displacement', 'Cylinders',
#        'Transmission', 'Drivetrain', 'Vehicle Class', 'Fuel Type',
#        'Fuel Barrels/Year', 'City MPG', 'Highway MPG', 'Combined MPG',
#        'CO2 Emission Grams/Mile', 'Fuel Cost/Year'],
#       dtype='object')

# %%
vehicles.pivot_table(index=["Make"])
# Out:
#                                     CO2 Emission Grams/Mile   City MPG  \
# Make
# AM General                                       611.358244  15.000000
# ASC Incorporated                                 555.437500  14.000000
# Acura                                            422.585325  18.890728
# Alfa Romeo                                       463.952115  17.097561
# American Motors Corporation                      505.758823  16.045455
# Aston Martin                                     672.617776  11.578947
# Audi                                             450.755841  17.565169
# Aurora Cars Ltd                                  592.466667  12.000000
# Autokraft Limited                                539.101103  14.000000
# BMW                                              457.474347  17.227788
# BMW Alpina                                       567.780556  13.666667
# Bentley                                          686.046662  10.913793
# ...
