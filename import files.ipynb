# %%
import sys
# !{sys.executable} -m pip install pandas xlrd openpyxl pymysql sqlalchemy

# %%
import pandas as pd


# Import comma-separated variable file
data = pd.read_csv('vehicles/vehicles.csv')
print(data)
# Out:
#                         Make                Model  Year  Engine Displacement  \
# 0                 AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1                 AM General     FJ8c Post Office  1984                  4.2
# 2                 AM General  Post Office DJ5 2WD  1985                  2.5
# 3                 AM General  Post Office DJ8 2WD  1985                  4.2
# 4           ASC Incorporated                  GNX  1987                  3.8
# 5                      Acura          2.2CL/3.0CL  1997                  2.2
# 6                      Acura          2.2CL/3.0CL  1997                  2.2
# 7                      Acura          2.2CL/3.0CL  1997                  3.0
# 8                      Acura          2.3CL/3.0CL  1998                  2.3
# 9                      Acura          2.3CL/3.0CL  1998                  2.3
# 10                     Acura          2.3CL/3.0CL  1998                  3.0
# ...

# %%
# Import tab-delimited file
data1 = pd.read_csv('vehicles/vehicles_tab.txt', sep='\t')
print(data1)
# Out:
#                         Make                Model  Year  Engine Displacement  \
# 0                 AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1                 AM General     FJ8c Post Office  1984                  4.2
# 2                 AM General  Post Office DJ5 2WD  1985                  2.5
# 3                 AM General  Post Office DJ8 2WD  1985                  4.2
# 4           ASC Incorporated                  GNX  1987                  3.8
# 5                      Acura          2.2CL/3.0CL  1997                  2.2
# 6                      Acura          2.2CL/3.0CL  1997                  2.2
# 7                      Acura          2.2CL/3.0CL  1997                  3.0
# 8                      Acura          2.3CL/3.0CL  1998                  2.3
# 9                      Acura          2.3CL/3.0CL  1998                  2.3
# 10                     Acura          2.3CL/3.0CL  1998                  3.0
# ...

# %%
# Import pipe-delimited file
data2 = pd.read_csv('vehicles/vehicles_pipe.txt', sep='|')
print(data2)
# Out:
#                         Make                Model  Year  Engine Displacement  \
# 0                 AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1                 AM General     FJ8c Post Office  1984                  4.2
# 2                 AM General  Post Office DJ5 2WD  1985                  2.5
# 3                 AM General  Post Office DJ8 2WD  1985                  4.2
# 4           ASC Incorporated                  GNX  1987                  3.8
# 5                      Acura          2.2CL/3.0CL  1997                  2.2
# 6                      Acura          2.2CL/3.0CL  1997                  2.2
# 7                      Acura          2.2CL/3.0CL  1997                  3.0
# 8                      Acura          2.3CL/3.0CL  1998                  2.3
# 9                      Acura          2.3CL/3.0CL  1998                  2.3
# 10                     Acura          2.3CL/3.0CL  1998                  3.0
# ...

# %%
data.to_csv('vehicles/lol.csv', index=False)

# %%
data3 = pd.read_excel('vehicles/vehicles.xlsx')
print(data3)

data3.to_excel('vehicles/lol.xlsx', index=False)
# Out:
#                         Make                Model  Year  Engine Displacement  \
# 0                 AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1                 AM General     FJ8c Post Office  1984                  4.2
# 2                 AM General  Post Office DJ5 2WD  1985                  2.5
# 3                 AM General  Post Office DJ8 2WD  1985                  4.2
# 4           ASC Incorporated                  GNX  1987                  3.8
# 5                      Acura          2.2CL/3.0CL  1997                  2.2
# 6                      Acura          2.2CL/3.0CL  1997                  2.2
# 7                      Acura          2.2CL/3.0CL  1997                  3.0
# 8                      Acura          2.3CL/3.0CL  1998                  2.3
# 9                      Acura          2.3CL/3.0CL  1998                  2.3
# 10                     Acura          2.3CL/3.0CL  1998                  3.0
# ...

# %%
data4 = pd.read_json('vehicles/vehicles.json', orient='records')
print(data4)
# Out:
#        CO2 Emission Grams/Mile  City MPG  Combined MPG  Cylinders  \
# 0                   522.764706        18            17          4
# 1                   683.615385        13            13          6
# 2                   555.437500        16            16          4
# 3                   683.615385        13            13          6
# 4                   555.437500        14            16          6
# 5                   403.954545        20            22          4
# 6                   370.291667        22            24          4
# 7                   444.350000        18            20          6
# 8                   403.954545        19            22          4
# 9                   370.291667        21            24          4
# 10                  444.350000        17            20          6
# 11                  403.954545        20            22          4
# 12                  370.291667        21            24          4
# ...

# %%
data4 = pd.read_json('vehicles/vehicles.json', orient='index')
print(data4)
# Out:
#                                                0      \
# CO2 Emission Grams/Mile                      522.765
# City MPG                                          18
# Combined MPG                                      17
# Cylinders                                          4
# Drivetrain                             2-Wheel Drive
# Engine Displacement                              2.5
# Fuel Barrels/Year                            19.3888
# Fuel Cost/Year                                  1950
# Fuel Type                                    Regular
# Highway MPG                                       17
# Make                                      AM General
# Model                              DJ Po Vehicle 2WD
# Transmission                         Automatic 3-spd
# Vehicle Class            Special Purpose Vehicle 2WD
# Year                                            1984
#
#                                                1      \
# CO2 Emission Grams/Mile                      683.615
# ...

# %%
data4 = pd.read_json('vehicles/vehicles.json', orient='values')
print(data4)
# Out:
#        CO2 Emission Grams/Mile  City MPG  Combined MPG  Cylinders  \
# 0                   522.764706        18            17          4
# 1                   683.615385        13            13          6
# 2                   555.437500        16            16          4
# 3                   683.615385        13            13          6
# 4                   555.437500        14            16          6
# 5                   403.954545        20            22          4
# 6                   370.291667        22            24          4
# 7                   444.350000        18            20          6
# 8                   403.954545        19            22          4
# 9                   370.291667        21            24          4
# 10                  444.350000        17            20          6
# 11                  403.954545        20            22          4
# 12                  370.291667        21            24          4
# ...

# %%
data4 = pd.read_json('vehicles/vehicles.json', orient='table')
print(data4)
# Out:
# --------------------------------------------------------------------
# TypeError                          Traceback (most recent call last)
# <ipython-input-17-867482bd0ae8> in <module>
# ----> 1 data4 = pd.read_json('vehicles/vehicles.json', orient='table')
#       2 print(data4)
#
# /usr/local/lib/python3.7/site-packages/pandas/io/json/json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     425         return json_reader
#     426
# --> 427     result = json_reader.read()
#     428     if should_close:
#     429         try:
#
# /usr/local/lib/python3.7/site-packages/pandas/io/json/json.py in read(self)
#     535             )
#     536         else:
# --> 537             obj = self._get_object_parser(self.data)
#     538         self.close()
#     539         return obj
#
# ...

# %%
import pymysql
from sqlalchemy import create_engine

engine = create_engine('mysql+pymysql://root:password@localhost/publications')

data5 = pd.read_sql_query('SELECT * FROM publications.employee', engine)
print(data5)
# Out:
#        emp_id      fname minit      lname  job_id  job_lvl pub_id  hire_date
# 0   A-C71970F       Aria             Cruz      10       87   1389 1991-10-26
# 1   A-R89858F    Annette           Roulet       6      152   9999 1990-02-21
# 2   AMD15433F        Ann     M      Devon       3      200   9952 1991-07-16
# 3   ARD36773F    Anabela     R  Domingues       8      100   0877 1993-01-27
# 4   CFH28514M     Carlos     F   Hernadez       5      211   9999 1989-04-21
# 5   CGS88322F     Carine     G    Schmitt      13       64   1389 1992-07-07
# 6   DBT39435M     Daniel     B     Tonini      11       75   0877 1990-01-01
# 7   DWR65030M      Diego     W       Roel       6      192   1389 1991-12-16
# 8   ENL44273F  Elizabeth     N    Lincoln      14       35   0877 1990-07-24
# 9   F-C16315M  Francisco            Chang       4      227   9952 1990-11-03
# 10  GHT50241M       Gary     H     Thomas       9      170   0736 1988-08-09
# ...

# %%
data.to_sql('employee2', engine, if_exists='replace', index=False)

# %%
pd.read_sql_query('SELECT * FROM publications.employee2', engine)
# Out:
#                         Make                Model  Year  Engine Displacement  \
# 0                 AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1                 AM General     FJ8c Post Office  1984                  4.2
# 2                 AM General  Post Office DJ5 2WD  1985                  2.5
# 3                 AM General  Post Office DJ8 2WD  1985                  4.2
# 4           ASC Incorporated                  GNX  1987                  3.8
# 5                      Acura          2.2CL/3.0CL  1997                  2.2
# 6                      Acura          2.2CL/3.0CL  1997                  2.2
# 7                      Acura          2.2CL/3.0CL  1997                  3.0
# 8                      Acura          2.3CL/3.0CL  1998                  2.3
# 9                      Acura          2.3CL/3.0CL  1998                  2.3
# 10                     Acura          2.3CL/3.0CL  1998                  3.0
# ...

# %%
#data cleaning
data6 = pd.read_csv('vehicles/vehicles_messy.csv')
print(data6)
# Out:
#        barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 0      15.695714         0.0        0.0        0.0      19      0.0        0
# 1      29.964545         0.0        0.0        0.0       9      0.0        0
# 2      12.207778         0.0        0.0        0.0      23      0.0        0
# 3      29.964545         0.0        0.0        0.0      10      0.0        0
# 4      17.347895         0.0        0.0        0.0      17      0.0        0
# 5      14.982273         0.0        0.0        0.0      21      0.0        0
# 6      13.184400         0.0        0.0        0.0      22      0.0        0
# 7      13.733750         0.0        0.0        0.0      23      0.0        0
# 8      12.677308         0.0        0.0        0.0      23      0.0        0
# 9      13.184400         0.0        0.0        0.0      23      0.0        0
# 10     12.677308         0.0        0.0        0.0      23      0.0        0
# ...

# %%
data6.head()
# Out:
#    barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 0  15.695714         0.0        0.0        0.0      19      0.0        0
# 1  29.964545         0.0        0.0        0.0       9      0.0        0
# 2  12.207778         0.0        0.0        0.0      23      0.0        0
# 3  29.964545         0.0        0.0        0.0      10      0.0        0
# 4  17.347895         0.0        0.0        0.0      17      0.0        0
#
#    cityA08U  cityCD  cityE  ...  mfrCode  c240Dscr  charge240b  c240bDscr  \
# 0       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 1       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 2       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 3       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 4       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
#
#                       createdOn                    modifiedOn  startStop  \
# ...

# %%
null_cols = data6.isnull().sum()
print(null_cols)
null_cols[null_cols > 0]
# Out:
# barrels08              0
# barrelsA08             0
# charge120              0
# charge240              0
# city08                 0
# city08U                0
# cityA08                0
# cityA08U               0
# cityCD                 0
# cityE                  0
# cityUF                 0
# co2                    0
# co2A                   0
# co2TailpipeAGpm        0
# co2TailpipeGpm         0
# comb08                 0
# comb08U                0
# combA08                0
# combA08U               0
# combE                  0
# combinedCD             0
# combinedUF             0
# cylinders              0
# displ                  0
# drive               1189
# engId                  0
# eng_dscr           15403
# feScore                0
# fuelCost08             0
# fuelCostA08            0
#                    ...
# rangeCity              0
# rangeCityA             0
# rangeHwy               0
# rangeHwyA              0
# trany                 11
# UCity                  0
# ...

# %%
null_displ = data6[(data6['displ'].isnull()==True)]
null_displ = null_displ[['year', 'make', 'model', 'trany', 'drive','fuelType','cylinders', 'displ']]
print(null_displ)
# Out:
# Empty DataFrame
# Columns: [year, make, model, trany, drive, fuelType, cylinders, displ]
# Index: []

# %%
data6[['displ', 'cylinders']] = data6[['displ', 'cylinders']].fillna(0)

# %%
data6[['displ', 'cylinders']]
# Out:
#        displ  cylinders
# 0        2.0        4.0
# 1        4.9       12.0
# 2        2.2        4.0
# 3        5.2        8.0
# 4        2.2        4.0
# 5        1.8        4.0
# 6        1.8        4.0
# 7        1.6        4.0
# 8        1.6        4.0
# 9        1.8        4.0
# 10       1.8        4.0
# 11       2.0        4.0
# 12       2.0        4.0
# 13       2.0        4.0
# 14       5.2        8.0
# 15       2.0        4.0
# 16       2.3        4.0
# 17       2.3        4.0
# 18       2.8        6.0
# 19       2.8        6.0
# 20       4.0        8.0
# 21       4.0        8.0
# 22       5.0       12.0
# 23       2.2        4.0
# 24       3.3        6.0
# 25       5.2        8.0
# 26       3.3        6.0
# 27       3.1        6.0
# 28       3.1        6.0
# 29       3.8        6.0
# ...      ...        ...
# 37813    2.2        4.0
# 37814    2.5        4.0
# 37815    2.5        4.0
# 37816    3.0        6.0
# 37817    3.0        6.0
# 37818    2.3        4.0
# ...

# %%
test = data6[(data['cylinders']==0) & (data6['displ']!=0)]
test[['year', 'make', 'model', 'trany', 'drive','fuelType','cylinders', 'displ']]
# Out:
# --------------------------------------------------------------------
# KeyError                           Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cylinders'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                           Traceback (most recent call last)
# <ipython-input-69-88bec498fd45> in <module>
# ...
